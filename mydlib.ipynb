# %%
import cv2
import dlib
import os
import sys
import random
# 存储位置
output_dir = 'F:/my/631907060127'
size = 64
 
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# 改变图片的亮度与对比度
 
def relight(img, light=1, bias=0):
    w = img.shape[1]
    h = img.shape[0]
    #image = []
    for i in range(0,w):
        for j in range(0,h):
            for c in range(3):
                tmp = int(img[j,i,c]*light + bias)
                if tmp > 255:
                    tmp = 255
                elif tmp < 0:
                    tmp = 0
                img[j,i,c] = tmp
    return img
 
#使用dlib自带的frontal_face_detector作为我们的特征提取器
detector = dlib.get_frontal_face_detector()
# 打开摄像头 参数为输入流，可以为摄像头或视频文件
camera = cv2.VideoCapture(0)
#camera = cv2.VideoCapture('C:/Users/CUNGU/Videos/Captures/wang.mp4')

index = 1
while True:
    if (index <= 20):#存储20张人脸特征图像
        print('Being processed picture %s' % index)
        # 从摄像头读取照片
        success, img = camera.read()
        # 转为灰度图片
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # 使用detector进行人脸检测
        dets = detector(gray_img, 1)
 
        for i, d in enumerate(dets):
            x1 = d.top() if d.top() > 0 else 0
            y1 = d.bottom() if d.bottom() > 0 else 0
            x2 = d.left() if d.left() > 0 else 0
            y2 = d.right() if d.right() > 0 else 0
 
            face = img[x1:y1,x2:y2]
            # 调整图片的对比度与亮度， 对比度与亮度值都取随机数，这样能增加样本的多样性
            face = relight(face, random.uniform(0.5, 1.5), random.randint(-50, 50))
 
            face = cv2.resize(face, (size,size))
 
            cv2.imshow('image', face)
 
            cv2.imwrite(output_dir+'/'+str(index)+'.jpg', face)
 
            index += 1
        key = cv2.waitKey(30) & 0xff
        if key == 27:
            break
    else:
        print('Finished!')
        # 释放摄像头 release camera
        camera.release()
        # 删除建立的窗口 delete all the windows
        cv2.destroyAllWindows()
        break
# Out:
# Being processed picture 1
# Being processed picture 2
# Being processed picture 3
# Being processed picture 4
# Being processed picture 5
# Being processed picture 6
# Being processed picture 7
# Being processed picture 8
# Being processed picture 9
# Being processed picture 10
# Being processed picture 11
# Being processed picture 12
# Being processed picture 13
# Being processed picture 14
# Being processed picture 15
# Being processed picture 16
# Being processed picture 17
# Being processed picture 18
# Being processed picture 19
# Being processed picture 20
# Finished!

# %%
from cv2 import cv2 as cv2
import os
import dlib
from skimage import io
import csv
import numpy as np
 
# 要读取人脸图像文件的路径
path_images_from_camera = "F:/my/"

# Dlib 正向人脸检测器
detector = dlib.get_frontal_face_detector()

# Dlib 人脸预测器
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# Dlib 人脸识别模型
# Face recognition model, the object maps human faces into 128D vectors
face_rec = dlib.face_recognition_model_v1("dlib_face_recognition_resnet_model_v1.dat")

# 返回单张图像的 128D 特征
def return_128d_features(path_img):
    img_rd = io.imread(path_img)
    s=path_img
    a=s[16:17]
    i1=str(a)
    a1=s[17:]
    str1="/"
    b=a1[a1.index(str1):-4]
    b1=b[1:]
    i2=str(b1)
    img_gray = cv2.cvtColor(img_rd, cv2.COLOR_BGR2RGB)
    faces = detector(img_gray, 1)
    for i in range(len(faces)):
        landmarks = np.matrix([[p.x, p.y] for p in predictor(img_rd,faces[i]).parts()])  
        for idx, point in enumerate(landmarks):
            # 68点的坐标
            pos = (point[0, 0], point[0, 1])
            add="F:/jupyter/feature/face"+i1+"_feature"+i2+".csv"
            with open(add, "a", newline="") as csvfile:
                writer1 = csv.writer(csvfile)
                writer1.writerow((idx,pos))
        print(add)
    print("%-40s %-20s" % ("检测到人脸的图像 / image with faces detected:", path_img), '\n')

    # 因为有可能截下来的人脸再去检测，检测不出来人脸了
    # 所以要确保是 检测到人脸的人脸图像 拿去算特征
    if len(faces) != 0:
        shape = predictor(img_gray, faces[0])
        face_descriptor = face_rec.compute_face_descriptor(img_gray, shape)
    else:
        face_descriptor = 0
        print("no face")

    return face_descriptor


# 将文件夹中照片特征提取出来, 写入 CSV
def return_features_mean_personX(path_faces_personX):
    features_list_personX = []
    photos_list = os.listdir(path_faces_personX)
    if photos_list:
        for i in range(len(photos_list)):
            # 调用return_128d_features()得到128d特征
            print("%-40s %-20s" % ("正在读的人脸图像 / image to read:", path_faces_personX + "/" + photos_list[i]))
            features_128d = return_128d_features(path_faces_personX + "/" + photos_list[i])
            #  print(features_128d)
            # 遇到没有检测出人脸的图片跳过
            if features_128d == 0:
                i += 1
            else:
                features_list_personX.append(features_128d)

    else:
        print("文件夹内图像文件为空 / Warning: No images in " + path_faces_personX + '/', '\n')

    # 计算 128D 特征的均值
    # N x 128D -> 1 x 128D
    if features_list_personX:
        features_mean_personX = np.array(features_list_personX).mean(axis=0)
    else:
        features_mean_personX = '0'

    return features_mean_personX


# 读取某人所有的人脸图像的数据
people = os.listdir(path_images_from_camera)
people.sort()
with open("F:/jupyter/feature/face_feature_mean.csv", "w", newline="") as csvfile: #程序会新建一个表格文件来保存特征值，方便以后比对
    writer = csv.writer(csvfile)
    for person in people:
        print("##### " + person + " #####")
        # Get the mean/average features of face/personX, it will be a list with a length of 128D
        features_mean_personX = return_features_mean_personX(path_images_from_camera + person)
        writer.writerow(features_mean_personX)
        print("特征均值 / The mean of features:", list(features_mean_personX))
        print('\n')
    print("所有录入人脸数据存入 / Save all the features of faces registered into: F:/jupyter/feature/face_feature_mean.csv")
# Out:
# ##### 631907060127 #####
# 正在读的人脸图像 / image to read:                F:/my/631907060127/1.jpg
# F:/jupyter/feature/face2_feature1.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/1.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/10.jpg
# F:/jupyter/feature/face2_feature10.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/10.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/11.jpg
# F:/jupyter/feature/face2_feature11.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/11.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/12.jpg
# F:/jupyter/feature/face2_feature12.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/12.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/13.jpg
# F:/jupyter/feature/face2_feature13.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/13.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/14.jpg
# F:/jupyter/feature/face2_feature14.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/14.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/15.jpg
# F:/jupyter/feature/face2_feature15.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/15.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/16.jpg
# F:/jupyter/feature/face2_feature16.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/16.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/17.jpg
# F:/jupyter/feature/face2_feature17.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/17.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/18.jpg
# F:/jupyter/feature/face2_feature18.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/18.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/19.jpg
# F:/jupyter/feature/face2_feature19.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/19.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/2.jpg
# F:/jupyter/feature/face2_feature2.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/2.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/20.jpg
# F:/jupyter/feature/face2_feature20.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/20.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/3.jpg
# F:/jupyter/feature/face2_feature3.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/3.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/4.jpg
# F:/jupyter/feature/face2_feature4.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/4.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/5.jpg
# F:/jupyter/feature/face2_feature5.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/5.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/6.jpg
# F:/jupyter/feature/face2_feature6.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/6.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/7.jpg
# F:/jupyter/feature/face2_feature7.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/7.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/8.jpg
# F:/jupyter/feature/face2_feature8.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/8.jpg
#
# 正在读的人脸图像 / image to read:                F:/my/631907060127/9.jpg
# F:/jupyter/feature/face2_feature9.csv
# 检测到人脸的图像 / image with faces detected:    F:/my/631907060127/9.jpg
#
# 特征均值 / The mean of features: [-0.06118244770914316, 0.08281798418611289, 0.06850057300180197, -0.08660616744309664, -0.1363425452262163, -0.018126887502148747, -0.10776996836066247, -0.13295939266681672, 0.1481218434870243, -0.1456811621785164, 0.23180980905890464, -0.04877343904227018, -0.18368869721889497, -0.08080903291702271, -0.09687429890036584, 0.18363591134548188, -0.1832917258143425, -0.12129047438502312, 0.01572257149964571, -0.002850404754281044, 0.06364787966012955, 0.03704041079618037, 0.003169770693057217, -0.020962111372500657, -0.0912315584719181, -0.38267248272895815, -0.09273863025009632, -0.0832246134057641, -0.010443653957918287, -0.04611112456768751, -0.03108694953843951, 0.051541521307080986, -0.1667614609003067, -0.036821482703089714, -0.011612574523314833, 0.09490054249763488, -0.030928047187626363, -0.06225510872900486, 0.12224777303636074, -0.008316696807742118, -0.2604301035404205, 0.02063370883697644, 0.0130988247692585, 0.22563135251402855, 0.17618486434221267, 0.0035292898304760457, 0.053128974977880716, -0.1330189321190119, 0.08509097397327423, -0.16885146498680115, 0.01869489545933902, 0.08770619593560695, 0.01653864250984043, 0.020940619218163193, 0.011051617539487779, -0.12511241734027861, 0.022575197042897344, 0.08927105069160461, -0.12501079998910428, -0.0055019122781232, 0.12550425194203854, -0.1077559445053339, -0.014532221457920968, -0.05928494073450565, 0.2135802038013935, 0.06587484227493405, -0.09644500650465489, -0.1893984518945217, 0.12553347907960416, -0.13921069093048571, -0.08283227868378162, 0.05422988962382078, -0.1209976114332676, -0.1531940944492817, -0.33455033153295516, 0.0011346106883138418, 0.3955749928951263, 0.09305395986884832, -0.14117850102484225, 0.04447229087818414, -0.04192096795886755, 0.022914167772978545, 0.1567952111363411, 0.14668941050767897, 0.029850752744823694, 0.04276071153581142, -0.12098711431026458, 0.018413487914949657, 0.20782093033194543, -0.08122831303626299, -0.04875629311427474, 0.1901766538619995, -0.042995189782232046, 0.10090292841196061, 0.017573669832199813, 0.08153519984334708, -0.07951948847621679, 0.08392343893647194, -0.1000776406377554, 0.028846951224841176, 0.08096040338277817, -0.02647881591692567, -0.012587260827422142, 0.1363174445927143, -0.1195160172879696, 0.1415703546255827, -0.037242054741363974, 0.05001800041645765, 0.028589655389077963, -0.049045341182500125, -0.05354172755032778, -0.028856238210573794, 0.15413068383932113, -0.2042192444205284, 0.18232714161276817, 0.17061230465769767, 0.06205958286300302, 0.14644383043050765, 0.1408068999648094, 0.03320588185451925, -0.03863687803968787, -0.0721105420961976, -0.27025066763162614, -0.022716951998881997, 0.028490273794159294, -0.03527828478254378, 0.08102472387254238, 0.03215378138702363]
#
#
# ##### known #####
# 文件夹内图像文件为空 / Warning: No images in F:/my/known/
#
# 特征均值 / The mean of features: ['0']
#
#
# ##### unknown #####
# 文件夹内图像文件为空 / Warning: No images in F:/my/unknown/
#
# 特征均值 / The mean of features: ['0']
#
#
# 所有录入人脸数据存入 / Save all the features of faces registered into: F:/jupyter/feature/face_feature_mean.csv

# %%
import os
import winsound # 系统音效
from playsound import playsound # 音频播放
import dlib          # 人脸处理的库 Dlib
import csv # 存入表格
import time
import sys
import numpy as np   # 数据处理的库 numpy
from cv2 import cv2 as cv2           # 图像处理的库 OpenCv
import pandas as pd  # 数据处理的库 Pandas


# 人脸识别模型，提取128D的特征矢量
# face recognition model, the object maps human faces into 128D vectors
# Refer this tutorial: http://dlib.net/python/index.html#dlib.face_recognition_model_v1
facerec = dlib.face_recognition_model_v1("dlib_face_recognition_resnet_model_v1.dat")#我这是在同一路径下的，dlib_face_recognition_resnet_model_v1.dat不在
#要写为绝对路径："D:/****/****/dlib_face_recognition_resnet_model_v1.dat"


# 计算两个128D向量间的欧式距离
# compute the e-distance between two 128D features
def return_euclidean_distance(feature_1, feature_2):
    feature_1 = np.array(feature_1)
    feature_2 = np.array(feature_2)
    dist = np.sqrt(np.sum(np.square(feature_1 - feature_2)))
    return dist


# 处理存放所有人脸特征的 csv
path_features_known_csv = "F:/jupyter/feature/face_feature_mean.csv"
csv_rd = pd.read_csv(path_features_known_csv, header=None)


# 用来存放所有录入人脸特征的数组
# the array to save the features of faces in the database
features_known_arr = []

# 读取已知人脸数据
# print known faces
for i in range(csv_rd.shape[0]):
    features_someone_arr = []
    for j in range(0, len(csv_rd.loc[i, :])):
        features_someone_arr.append(csv_rd.loc[i, :][j])
    features_known_arr.append(features_someone_arr)
print("Faces in Database：", len(features_known_arr))

# Dlib 检测器和预测器
# The detector and predictor will be used
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')#我这是在同一路径下的，shape_predictor_68_face_landmarks.dat不在
#要写为绝对路径："D:/****/****/shape_predictor_68_face_landmarks.dat

# 创建 cv2 摄像头对象
# cv2.VideoCapture(0) to use the default camera of PC,
# and you can use local video name by use cv2.VideoCapture(filename)
cap = cv2.VideoCapture(0)

# cap.set(propId, value)
# 设置视频参数，propId 设置的视频参数，value 设置的参数值
cap.set(3, 480)

# cap.isOpened() 返回 true/false 检查初始化是否成功
# when the camera is open
while cap.isOpened():

    flag, img_rd = cap.read()
    kk = cv2.waitKey(1)

    # 取灰度
    img_gray = cv2.cvtColor(img_rd, cv2.COLOR_RGB2GRAY)

    # 人脸数 faces
    faces = detector(img_gray, 0)

    # 待会要写的字体 font to write later
    font = cv2.FONT_HERSHEY_COMPLEX

    # 存储当前摄像头中捕获到的所有人脸的坐标/名字
    # the list to save the positions and names of current faces captured
    pos_namelist = []
    name_namelist = []

    # 按下 q 键退出
    # press 'q' to exit
    if kk == ord('q'):
        break
    else:
        # 检测到人脸 when face detected
        if len(faces) != 0:  
            # 获取当前捕获到的图像的所有人脸的特征，存储到 features_cap_arr
            # get the features captured and save into features_cap_arr
            features_cap_arr = []
            for i in range(len(faces)):
                shape = predictor(img_rd, faces[i])
                features_cap_arr.append(facerec.compute_face_descriptor(img_rd, shape))

            # 遍历捕获到的图像中所有的人脸
            # traversal all the faces in the database
            for k in range(len(faces)):
                print("##### camera person", k+1, "#####")
                # 让人名跟随在矩形框的下方
                # 确定人名的位置坐标
                # 先默认所有人不认识，是 unknown
                # set the default names of faces with "unknown"
                name_namelist.append("unknown")

                # 每个捕获人脸的名字坐标 the positions of faces captured
                pos_namelist.append(tuple([faces[k].left(), int(faces[k].bottom() + (faces[k].bottom() - faces[k].top())/4)]))

                # 对于某张人脸，遍历所有存储的人脸特征
                # for every faces detected, compare the faces in the database
                e_distance_list = []
                for i in range(len(features_known_arr)):
                    # 如果 person_X 数据不为空
                    if str(features_known_arr[i][0]) != '0.0':
                        print("with person", str(i + 1), "the e distance: ", end='')
                        e_distance_tmp = return_euclidean_distance(features_cap_arr[k], features_known_arr[i])
                        print(e_distance_tmp)
                        e_distance_list.append(e_distance_tmp)
                    else:
                        # 空数据 person_X
                        e_distance_list.append(999999999)
                # 找出最接近的一个人脸数据是第几个
                # Find the one with minimum e distance
                similar_person_num = e_distance_list.index(min(e_distance_list))
                print("Minimum e distance with person", int(similar_person_num)+1)
                
                # 计算人脸识别特征与数据集特征的欧氏距离
                # 距离小于0.4则标出为可识别人物
                if min(e_distance_list) < 0.4:
                    # 这里可以修改摄像头中标出的人名
                    # Here you can modify the names shown on the camera
                    # 1、遍历文件夹目录
                    folder_name = 'F:/my/'
                    # 最接近的人脸
                    sum=similar_person_num+1
                    key_id=1 # 从第一个人脸数据文件夹进行对比
                    # 获取文件夹中的文件名:1wang、2zhou、3...
                    file_names = os.listdir(folder_name)
                    for name in file_names:
                        # print(name+'->'+str(key_id))
                        if sum ==key_id:
                            #winsound.Beep(300,500)# 响铃：300频率，500持续时间
                            name_namelist[k] = name[1:]#人名删去第一个数字（用于视频输出标识）
                        key_id += 1
                    # 播放欢迎光临音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/welcome.wav')
                    # print("May be person "+str(int(similar_person_num)+1))
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor人脸图像文件的路径
                        path_visitors_save_dir = "F:/my/known" #自己在faces路径下先建一个known文件，否则可能会报错
                        # 存储格式：2019-06-24-14-33-40wang.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        save_name = str(now_time)+str(name_namelist[k])+'.jpg'
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ save_name    
                        # 遍历visitor文件夹所有文件名
                        visitor_names = os.listdir(path_visitors_save_dir)
                        visitor_name=''
                        for name in visitor_names:
                            # 名字切片到分钟数：2019-06-26-11-33-00wangyu.jpg
                            visitor_name=(name[0:16]+'-00'+name[19:])
                        # print(visitor_name)
                        visitor_save=(save_name[0:16]+'-00'+save_name[19:])
                        # print(visitor_save)
                        # 一分钟之内重复的人名不保存
                        if visitor_save!=visitor_name:
                            cv2.imwrite(save_path, face)
                            print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+str(name_namelist[k])+'.jpg')
                        else:
                            print('重复，未保存！')
                            
                else:
                    # 播放无法识别音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/sorry.wav')
                    print("Unknown person")
                    # -----保存图片-------
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor-》unknown人脸图像文件的路径
                        path_visitors_save_dir = "F:/my/unknown"#自己在faces路径下先建一个unknown文件，否则可能会报错
                        # 存储格式：2019-06-24-14-33-40unknown.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ str(now_time)+'unknown.jpg'
                        cv2.imwrite(save_path, face)
                        print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+'unknown.jpg')
                
                # 矩形框
                # draw rectangle
                for kk, d in enumerate(faces):
                    # 绘制矩形框
                    cv2.rectangle(img_rd, tuple([d.left(), d.top()]), tuple([d.right(), d.bottom()]), (0, 255, 255), 2)
                print('\n')

            # 在人脸框下面写人脸名字
            # write names under rectangle
            for i in range(len(faces)):
                cv2.putText(img_rd, name_namelist[i], pos_namelist[i], font, 0.8, (0, 255, 255), 1, cv2.LINE_AA)

    print("Faces in camera now:", name_namelist, "\n")

    #cv2.putText(img_rd, "Press 'q': Quit", (20, 450), font, 0.8, (84, 255, 159), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Face Recognition", (20, 40), font, 1, (0, 0, 255), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Visitors: " + str(len(faces)), (20, 100), font, 1, (0, 0, 255), 1, cv2.LINE_AA)

    # 窗口显示 show with opencv
    cv2.imshow("camera", img_rd)
    k = cv2.waitKey(1)
    if k == 27:    # press 'ESC' to quit
        break
# 释放摄像头 release camera
cap.release()

# 删除建立的窗口 delete all the windows
cv2.destroyAllWindows()
# Out:
# Faces in Database： 3
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []

# %%
import os
import winsound # 系统音效
from playsound import playsound # 音频播放
import dlib          # 人脸处理的库 Dlib
import csv # 存入表格
import time
import sys
import numpy as np   # 数据处理的库 numpy
from cv2 import cv2 as cv2           # 图像处理的库 OpenCv
import pandas as pd  # 数据处理的库 Pandas


# 人脸识别模型，提取128D的特征矢量
# face recognition model, the object maps human faces into 128D vectors
# Refer this tutorial: http://dlib.net/python/index.html#dlib.face_recognition_model_v1
facerec = dlib.face_recognition_model_v1("dlib_face_recognition_resnet_model_v1.dat")#我这是在同一路径下的，dlib_face_recognition_resnet_model_v1.dat不在
#要写为绝对路径："D:/****/****/dlib_face_recognition_resnet_model_v1.dat"


# 计算两个128D向量间的欧式距离
# compute the e-distance between two 128D features
def return_euclidean_distance(feature_1, feature_2):
    feature_1 = np.array(feature_1)
    feature_2 = np.array(feature_2)
    dist = np.sqrt(np.sum(np.square(feature_1 - feature_2)))
    return dist


# 处理存放所有人脸特征的 csv
path_features_known_csv = "F:/jupyter/feature/face_feature_mean.csv"
csv_rd = pd.read_csv(path_features_known_csv, header=None)


# 用来存放所有录入人脸特征的数组
# the array to save the features of faces in the database
features_known_arr = []

# 读取已知人脸数据
# print known faces
for i in range(csv_rd.shape[0]):
    features_someone_arr = []
    for j in range(0, len(csv_rd.loc[i, :])):
        features_someone_arr.append(csv_rd.loc[i, :][j])
    features_known_arr.append(features_someone_arr)
print("Faces in Database：", len(features_known_arr))

# Dlib 检测器和预测器
# The detector and predictor will be used
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')#我这是在同一路径下的，shape_predictor_68_face_landmarks.dat不在
#要写为绝对路径："D:/****/****/shape_predictor_68_face_landmarks.dat

# 创建 cv2 摄像头对象
# cv2.VideoCapture(0) to use the default camera of PC,
# and you can use local video name by use cv2.VideoCapture(filename)
cap = cv2.VideoCapture(0)

# cap.set(propId, value)
# 设置视频参数，propId 设置的视频参数，value 设置的参数值
cap.set(3, 480)

# cap.isOpened() 返回 true/false 检查初始化是否成功
# when the camera is open
while cap.isOpened():

    flag, img_rd = cap.read()
    kk = cv2.waitKey(1)

    # 取灰度
    img_gray = cv2.cvtColor(img_rd, cv2.COLOR_RGB2GRAY)

    # 人脸数 faces
    faces = detector(img_gray, 0)

    # 待会要写的字体 font to write later
    font = cv2.FONT_HERSHEY_COMPLEX

    # 存储当前摄像头中捕获到的所有人脸的坐标/名字
    # the list to save the positions and names of current faces captured
    pos_namelist = []
    name_namelist = []

    # 按下 q 键退出
    # press 'q' to exit
    if kk == ord('q'):
        break
    else:
        # 检测到人脸 when face detected
        if len(faces) != 0:  
            # 获取当前捕获到的图像的所有人脸的特征，存储到 features_cap_arr
            # get the features captured and save into features_cap_arr
            features_cap_arr = []
            for i in range(len(faces)):
                shape = predictor(img_rd, faces[i])
                features_cap_arr.append(facerec.compute_face_descriptor(img_rd, shape))

            # 遍历捕获到的图像中所有的人脸
            # traversal all the faces in the database
            for k in range(len(faces)):
                print("##### camera person", k+1, "#####")
                # 让人名跟随在矩形框的下方
                # 确定人名的位置坐标
                # 先默认所有人不认识，是 unknown
                # set the default names of faces with "unknown"
                name_namelist.append("unknown")

                # 每个捕获人脸的名字坐标 the positions of faces captured
                pos_namelist.append(tuple([faces[k].left(), int(faces[k].bottom() + (faces[k].bottom() - faces[k].top())/4)]))

                # 对于某张人脸，遍历所有存储的人脸特征
                # for every faces detected, compare the faces in the database
                e_distance_list = []
                for i in range(len(features_known_arr)):
                    # 如果 person_X 数据不为空
                    if str(features_known_arr[i][0]) != '0.0':
                        print("with person", str(i + 1), "the e distance: ", end='')
                        e_distance_tmp = return_euclidean_distance(features_cap_arr[k], features_known_arr[i])
                        print(e_distance_tmp)
                        e_distance_list.append(e_distance_tmp)
                    else:
                        # 空数据 person_X
                        e_distance_list.append(999999999)
                # 找出最接近的一个人脸数据是第几个
                # Find the one with minimum e distance
                similar_person_num = e_distance_list.index(min(e_distance_list))
                print("Minimum e distance with person", int(similar_person_num)+1)
                
                # 计算人脸识别特征与数据集特征的欧氏距离
                # 距离小于0.4则标出为可识别人物
                if min(e_distance_list) < 0.4:
                    # 这里可以修改摄像头中标出的人名
                    # Here you can modify the names shown on the camera
                    # 1、遍历文件夹目录
                    folder_name = 'F:/my'
                    # 最接近的人脸
                    sum=similar_person_num+1
                    key_id=1 # 从第一个人脸数据文件夹进行对比
                    # 获取文件夹中的文件名:1wang、2zhou、3...
                    file_names = os.listdir(folder_name)
                    for name in file_names:
                        # print(name+'->'+str(key_id))
                        if sum ==key_id:
                            #winsound.Beep(300,500)# 响铃：300频率，500持续时间
                            name_namelist[k] = name[1:]#人名删去第一个数字（用于视频输出标识）
                        key_id += 1
                    # 播放欢迎光临音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/welcome.wav')
                    # print("May be person "+str(int(similar_person_num)+1))
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor人脸图像文件的路径
                        path_visitors_save_dir = "F:/my/known" #自己在faces路径下先建一个known文件，否则可能会报错
                        # 存储格式：2019-06-24-14-33-40wang.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        save_name = str(now_time)+str(name_namelist[k])+'.jpg'
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ save_name    
                        # 遍历visitor文件夹所有文件名
                        visitor_names = os.listdir(path_visitors_save_dir)
                        visitor_name=''
                        for name in visitor_names:
                            # 名字切片到分钟数：2019-06-26-11-33-00wangyu.jpg
                            visitor_name=(name[0:16]+'-00'+name[19:])
                        # print(visitor_name)
                        visitor_save=(save_name[0:16]+'-00'+save_name[19:])
                        # print(visitor_save)
                        # 一分钟之内重复的人名不保存
                        if visitor_save!=visitor_name:
                            cv2.imwrite(save_path, face)
                            print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+str(name_namelist[k])+'.jpg')
                        else:
                            print('重复，未保存！')
                            
                else:
                    # 播放无法识别音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/sorry.wav')
                    print("Unknown person")
                    # -----保存图片-------
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor-》unknown人脸图像文件的路径
                        path_visitors_save_dir = "F:/my/unknown"#自己在faces路径下先建一个unknown文件，否则可能会报错
                        # 存储格式：2019-06-24-14-33-40unknown.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ str(now_time)+'unknown.jpg'
                        cv2.imwrite(save_path, face)
                        print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+'unknown.jpg')
                
                # 矩形框
                # draw rectangle
                for kk, d in enumerate(faces):
                    # 绘制矩形框
                    cv2.rectangle(img_rd, tuple([d.left(), d.top()]), tuple([d.right(), d.bottom()]), (0, 255, 255), 2)
                print('\n')

            # 在人脸框下面写人脸名字
            # write names under rectangle
            for i in range(len(faces)):
                cv2.putText(img_rd, name_namelist[i], pos_namelist[i], font, 0.8, (0, 255, 255), 1, cv2.LINE_AA)

    print("Faces in camera now:", name_namelist, "\n")

    #cv2.putText(img_rd, "Press 'q': Quit", (20, 450), font, 0.8, (84, 255, 159), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Face Recognition", (20, 40), font, 1, (0, 0, 255), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Visitors: " + str(len(faces)), (20, 100), font, 1, (0, 0, 255), 1, cv2.LINE_AA)

    # 窗口显示 show with opencv
    cv2.imshow("camera", img_rd)
    k = cv2.waitKey(1)
    if k == 27:    # press 'ESC' to quit
        break
# 释放摄像头 release camera
cap.release()

# 删除建立的窗口 delete all the windows
cv2.destroyAllWindows()
# Out:
# Faces in Database： 3
# ##### camera person 1 #####
# with person 1 the e distance: 0.31676008969628233
# Minimum e distance with person 1
# 新存储：F:/my/known/2021-11-19-14-15-3331907060127.jpg
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3129064206727209
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29201562986714424
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28408859593766594
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27756116422558963
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2693914322902721
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2677245548753655
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25910840170600763
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26614969050279313
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2678485122171664
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2776021153232229
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29067746335540545
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28363767958718994
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2611202005447229
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2442439760488449
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24541464432497237
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2528289319352002
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2558912654168544
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25568070062056864
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24591698724497288
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24882076260434177
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2701409567831093
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2730433270462294
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23856630316760064
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2588569556170204
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2850179735366666
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2595768171683403
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2545126609579842
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25836572008512154
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2562310108901976
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2581904280851135
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2219584871535671
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23571203518842343
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22730405641894233
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23618024055215442
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2635558421440757
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24928180665709063
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23771443918080995
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23218990281453375
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26910684367256105
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28504129631668496
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2725363340470274
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24394579635882255
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24073395407824486
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2639675168010413
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26467420306463846
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27113421740903326
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26236930115928503
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2803259903185913
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26271237974928346
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3055875027309323
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30846145576054873
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31554076850618873
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2896932197799954
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24861658131745565
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2664355088562854
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28418857271557063
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29215595300260866
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3083779925030483
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3053864113851304
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30039638762914445
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2883725725382062
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.303339365294794
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25839882986549423
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2498999427114753
# Minimum e distance with person 1
# 新存储：F:/my/known/2021-11-19-14-16-0031907060127.jpg
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26001717849441935
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2737866293989102
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2848574914539096
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2867364939181863
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2590983639365587
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2665637687368179
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26746739187868707
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2942428981098259
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2820126538691863
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2982273660327676
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26079753964850555
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25797749611975285
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27871982505398507
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27371084757007624
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2662045192300721
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2795326593314733
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2637870795486161
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27523924594442
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28250538541218434
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2803950170703455
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28087642152968173
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28147787703195515
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30588640071850787
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.32325139437499073
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3687633366249359
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.374406030509713
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34687158601797863
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.288877586409217
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2623908555904543
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27642248514934775
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33291732351750675
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33563182695506427
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31616891670024727
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2996664512340781
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29099086297913485
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3071128736600367
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.313936225570098
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2984925938633219
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2890724667293199
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30748121378185067
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3008657842089274
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2907894201453783
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3076334674652899
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2965630359778967
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30690813639945996
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29059279783549136
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2951576055872987
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2912224915084674
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2805246305600697
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2870563806378953
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2960492802096207
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2996075878484385
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2893156305967209
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2977642572618883
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30227181588496943
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29853265761609
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28590197222731023
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3021538148433307
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28511799765453055
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3079183436990254
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3137654511129195
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2930998785614174
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27858054458934445
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2816523290835334
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2733294826927583
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2784541132507459
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30514773146833973
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31157396448847974
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3100145278596106
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29051085471674837
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33434427602070893
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3155817958350224
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33289336516579604
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31114998313936637
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.32210944343620346
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35767331132796615
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34206835638201244
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.32739204668782607
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3024560602614271
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3054841921464081
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.32210938643514286
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31859959487914385
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3085885025336903
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3060399022913269
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23439745872958276
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2509552689402198
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24525314051465505
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24136212913179309
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26243026392106983
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23042600029562893
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2604644366484283
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24942113871852542
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26001810105158857
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25574928879327324
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2377350051511741
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24419662972862935
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24808208496997933
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2627738426786495
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2690769371133166
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26517949321878265
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2577774995761563
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2693749898633703
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2562515956085108
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2652101832948083
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25367711426703626
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2761164098016286
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27847657005838794
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2778059907517455
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2658571716637434
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2784768088126276
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2770412053551003
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28229689497050214
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.270225043380721
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27772506861673174
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2858413786263444
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2718273051982877
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2612970736434434
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2648447516491663
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2703091490036391
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28659646021260693
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26758847575498124
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3442983495674642
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3082052832997898
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28239100559272406
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2664115466480184
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3073855546321679
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29449101471090333
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30610002315163354
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30481961567128735
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2977273939235784
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30158889874499595
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27516524648632384
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23247088143587524
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2243308424792637
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22384848897764884
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2239987549936861
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24922192625541026
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25332660099106113
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24655717205187333
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24261818279321937
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.249055983536485
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2619588992521572
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2697164995874777
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2565255634304727
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2705900100634075
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25966970365477526
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27618470681386964
# Minimum e distance with person 1
# 新存储：F:/my/known/2021-11-19-14-17-0031907060127.jpg
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25156842717500105
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22838787556321505
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2577530054980768
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2268670005777731
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2265894515691938
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.264904028286013
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2807602260928748
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2680704073115993
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27163012020730737
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2522575449131003
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2620391644403752
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2540966553383756
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2442834469874509
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.246767244986755
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2557120136643698
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24504067155162682
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26366565181168383
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2372456769982856
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2578788679203009
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25320655443768636
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27959018970678445
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26348836701774614
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26059536576659986
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2715366778223902
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2911437891970995
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2818737273553548
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26671009735051066
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2773955344576759
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28711790861621145
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2761590201543002
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2828798739349238
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28302703391230827
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2707260596048644
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28197401921373116
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.288622625525686
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3074240008685102
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31423234586784327
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30546951224116
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33957769637144414
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34770190874067053
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3490163518575891
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3326546770203243
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34245383026559656
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.32402010913332213
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3546357943337857
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3758897859974483
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.370357284286438
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34866510474353346
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36323593084376665
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35039240375241765
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3687759555779349
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3395282884473782
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3811711626600963
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.38362038489856054
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3729651972828812
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3794228017580422
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.374179773433489
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3825534733552479
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3789885455800087
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3509985971727465
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35155189352530314
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35012442466101645
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.364518959659121
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3542663122090219
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34711561327390883
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3674763251455223
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35883039560813446
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3350344202549688
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34756899933681773
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3758580664381139
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34545573697577847
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3527362240922812
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3658199107239073
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3685929985301845
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3427331048002406
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36007582600545734
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3523376416684536
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3589461112236513
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3577959990397725
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36436877505178444
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3138305027318337
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.31007976098282153
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33085958021712814
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3174934024144766
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33500447084333035
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33663667041511963
# Minimum e distance with person 1
# 重复，未保存！
#
# ...
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2678169286745251
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25503649168591985
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2618052631495729
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27050872304879986
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2539484519686307
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27187411832176817
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2839682031424947
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2798107125239947
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2814711031988043
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2670656342277906
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2741395216122733
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24225833193028076
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24674826781231707
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2544959422002661
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2579893335567559
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2491529824872877
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25757273713551315
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24836370118027548
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2517580966101968
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25458755117263
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2773478809539984
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2517206654199318
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27011481186834846
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3023879863466835
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2650002828634178
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2725338673114969
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2691759396603504
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.276606920303121
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22870174615685265
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25886492833346314
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24605661799541226
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23774536650463196
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26055720931864623
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2678081110101695
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2531237825929371
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25801029744146575
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25888519623438255
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25480765336938477
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27008897612321525
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26646871760071644
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2523767273169205
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2705090533477725
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2336575415062139
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2521306184969633
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23226579308259912
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24750744782963255
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24213695476089886
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2561298028845739
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2560380873623346
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22657795698945707
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24600029561595818
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27327592290008085
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2530625798387399
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23592118989495287
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23322592584586455
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.23000712522419003
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24931233481955736
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.22880695134175805
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.260787582478935
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3044647230857369
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4095269458672667
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/my/unknown/2021-11-19-14-30-51unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.4233329081284257
# Minimum e distance with person 1
# Unknown person
# 新存储：F:/my/unknown/2021-11-19-14-30-51unknown.jpg
#
#
# Faces in camera now: ['unknown']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3815249268939343
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# Faces in camera now: []
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35503312259007036
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3296044341128115
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.348760684702957
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36676056654687317
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3169449899531283
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.30994500716630247
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2968659585011924
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2979922301268609
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28414859956128025
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29891231471325663
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2520571499772073
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2517040875488435
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2738346292535497
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26091200971317663
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2966341723501195
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.28555042575917544
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2954191453967106
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25751891904147417
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2630817197994191
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2856253881006667
# Minimum e distance with person 1
# 新存储：F:/my/known/2021-11-19-14-31-0031907060127.jpg
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26185805189799627
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.29234964530465735
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2902427728134861
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27971389881696673
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2899626981406227
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27431400211338347
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2436590334491185
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.26600913696130013
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.24450166686642696
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2478444581752108
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2665352162615366
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.27210977430030053
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25810705251310584
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.25471929898504225
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.2611382847872539
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['31907060127']
